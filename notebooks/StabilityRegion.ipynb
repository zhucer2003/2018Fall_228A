# %% [markdown]
# ## Plot the stability region of multiple methods by brute force calculation
#
# A point $z$ is in the stable region if all roots corresponding to the characteristic polynomial has absolute value less than 1.

# %%
# Need the polynomials package first
#Pkg.update()
#Pkg.add("Polynomials")

# %%
using Polynomials # need to install this by Pkg.add("Polynomials")
using PyPlot
using LinearAlgebra

# Old version does not have ndgrid
function ndgrid(v1::AbstractVector{T}, v2::AbstractVector{T}) where T
    m, n = length(v1), length(v2)
    v1 = reshape(v1, m, 1)
    v2 = reshape(v2, 1, n)
    (repeat(v1, 1, n), repeat(v2, m, 1))
end

function RAS(alpha,beta)
    N=201
    x1d=range(-3.0,stop=3.0,length=N)
    X,Y=ndgrid(x1d,x1d)
    Z=zeros(size(X))
    @assert(length(alpha)==length(beta))
    for j = 1 : prod(size(X))
        lam = X[j] + im*Y[j]
        # println(alpha-lam*beta)
        w = roots(Poly(alpha-lam*beta))
        if(isempty(w))
            Z[j] = 0
        else 
            if(maximum(abs.(w))<=1.0)
                Z[j] = 1
            else
                Z[j] = 0
            end
        end
    end
    return X,Y,Z
end

# %%
# Forward Euler
X,Y,Z=RAS([-1.0,1.0],[1.0,0.0])
figure(figsize=(4,4))
contourf(X,Y,Z,[0.00,0.99,1.01],colors=("r","b"))
# Out:
# Figure(PyObject <Figure size 400x400 with 1 Axes>)
# ┌ Warning: `assert` is deprecated, use `@assert` instead.
# │   caller = RAS(::Array{Float64,1}, ::Array{Float64,1}) at In[4]:18
# └ @ Main ./In[4]:18
# PyObject <matplotlib.contour.QuadContourSet object at 0x7fedc98ae9b0>

# %%
# Backward Euler
X,Y,Z=RAS([-1.0,1.0],[0.0,1.0])
figure(figsize=(4,4))
contourf(X,Y,Z,[0.00,0.99,1.01],colors=("r","b"))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f0e41cd7b50>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7f0e418f0090>

# %%
# Trapezoidal Euler
X,Y,Z=RAS([-1.0,1.0],[0.5,0.5])
figure(figsize=(4,4))
contourf(X,Y,Z,[0.00,0.99,1.01],colors=("r","b"))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f149e842588>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7f1465ac98d0>

# %%
# Midpoint
X,Y,Z=RAS([-0.5,0.0,+0.5],[0.0,1.0,0.0])
figure(figsize=(4,4))
contourf(X,Y,Z,[0.00,0.99,1.01],colors=("r","b"))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f6785b18438>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7f67852fcbe0>

# %%
# AB2

X,Y,Z=RAS([0,-1,1],[-1/2,3/2,0])
figure(figsize=(4,4))
contourf(X,Y,Z,[0.00,0.99,1.01],colors=("r","b"))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f149e839668>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7f1465aaef98>

# %%
# AB4

X,Y,Z=RAS([0,0,0,-1,1],[-9/24,37/24,-59/24,55/24,0])
figure(figsize=(4,4))
contourf(X,Y,Z,[0.00,0.99,1.01],colors=("r","b"))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f1465aeefd0>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7f1465a12eb8>

# %%
# AM4

X,Y,Z=RAS([0,0,0,-1,1],[-19,106,-264,646,251]/720)
figure(figsize=(4,4))
contourf(X,Y,Z,[0.00,0.99,1.01],colors=("r","b"))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f6784f32860>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7f6784e8e470>

# %%
# Milne

X,Y,Z=RAS([-1,0,1],[1/3,4/3,1/3])
figure(figsize=(4,4))
contourf(X,Y,Z,[0.00,0.99,1.01],colors=("r","b"))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f6784f076a0>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7f6784e7aa90>

# %%
# BDF2

X,Y,Z=RAS([1/3,-4/3,1],[0,0,2/3])
figure(figsize=(4,4))
contourf(X,Y,Z,[0.00,0.99,1.01],colors=("r","b"))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f678545ad68>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7f67850c6390>

# %%
# BDF6
# This one chooses a larger plot region

X,Y,Z=RAS([10,-72,225,-400,450,-360,147]/147,[0,0,0,0,0,0,60/147])
figure(figsize=(4,4))
contourf(X,Y,Z,[0.00,0.99,1.01],colors=("r","b"))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f1465a24160>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7f1464fd4eb8>

# %%
function RASRK(A,b)
    N=200
    x1d=LinRange(-5.0,5.0,N)
    X,Y=ndgrid(x1d,x1d)
    Z=zeros(size(X))
    M = size(b,1)
    @assert(size(A,1)==size(A,2) & size(A,1)==M)
    e=ones(M)
    for j = 1 : prod(size(X))
        lam = X[j] + im*Y[j]
        R = 1.0+b'*inv(Matrix(I,M,M)-lam*A)*e*lam
        if(abs(R[1])<=1.0)
            Z[j] = 1.0
        else 
            Z[j] = 0.0
        end
    end
    return X,Y,Z    
end
# Out:
# RASRK (generic function with 1 method)

# %%
# RK2
A = [0 0
    0.5 0]
b = [0.0, 1.0]
X,Y,Z=RASRK(A,b)
figure(figsize=(4,4))
contourf(X,Y,Z,[0.00,0.99,1.01],colors=("r","b"))
# Out:
# Figure(PyObject <Figure size 400x400 with 1 Axes>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7fedcf9a6a20>

# %%
# RK4
A = [0 0 0 0
0.5 0 0 0 
0 0.5 0 0
0 0 1.0 0]
b = [1.0,2.0,2.0,1.0]/6.0
X,Y,Z=RASRK(A,b)
figure(figsize=(4,4))
contourf(X,Y,Z,[0.00,0.99,1.01],colors=("r","b"))
# Out:
# Figure(PyObject <Figure size 400x400 with 1 Axes>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7fedcf982208>

# %%
# Gauss-Legendre 1
A = [0.5]
b = [1.0]
X,Y,Z=RASRK(A,b)
figure(figsize=(4,4))
contourf(X,Y,Z,[0.00,0.99,1.01],colors=("r","b"))
# Out:
# Figure(PyObject <Figure size 400x400 with 1 Axes>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7fedc94e59e8>

# %%
# Gauss-Legendre 2
A = [1.0/4.0 1.0/4.0 - sqrt(3.0)/6.0
    1.0/4.0+sqrt(3.0)/6.0 1.0/4.0]
b = [0.5, 0.5]
X,Y,Z=RASRK(A,b)
figure(figsize=(4,4))
contourf(X,Y,Z,[0.00,0.99,1.01],colors=("r","b"))
# Out:
# Figure(PyObject <Figure size 400x400 with 1 Axes>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7fedc94c2128>

# %%
# Gauss-Legendre 3
A = [5.0/36.0  2.0/9.0-sqrt(15.0)/15.0  5.0/36.0-sqrt(15.0)/30.0
    5.0/36.0+sqrt(15.0)/24.0   2.0/9.0   5.0/36.0 - sqrt(15.0)/24.0
    5.0/36.0+sqrt(15.0)/30.0   2.0/9.0+sqrt(15.0)/15.0   5.0/36.0]
b = [5.0/18.0, 4.0/9.0, 5.0/18.0]
X,Y,Z=RASRK(A,b)
figure(figsize=(4,4))
contourf(X,Y,Z,[0.00,0.99,1.01],colors=("r","b"))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f4fae779080>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7f4fae6f7e48>
