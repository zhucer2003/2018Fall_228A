# %%
using PyPlot
f=figure(1)

A = 
[1 2;
2 1];

v = [1,-1.001]
n = 15
v = v / sqrt(v[1]^2+v[2]^2)

for i = 1 : n
    plot(v[1],v[2],"o",label=string(i))
    v = A*v
    v = v / sqrt(v[1]^2+v[2]^2)
end
axis([-2,2,-2,2])
legend()
println(v)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f093de88a10>)
# [-0.707205, -0.707008]
